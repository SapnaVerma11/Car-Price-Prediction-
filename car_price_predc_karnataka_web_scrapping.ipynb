# %% [markdown]
# # OLX karnataka

# %%
# importing required libraries.
import pandas as pd
import selenium
import time

#importing Webdriver
from selenium import webdriver

#importing Exception Handling
from selenium.common.exceptions import NoSuchElementException
#importing keys
from selenium.webdriver.common.keys import Keys

# %%
#connecting the web driver.
driver=webdriver.Chrome(r'C:\Program Files (x86)\chromedriver_win32\chromedriver.exe')

# %%
#connecting the website.
driver.get('https://www.olx.in/karnataka_g2001159/cars_c84')
time.sleep(2)

# %%
#creating empty list
Car_Brand=[]
Car_Model=[]
Car_Variant=[]
Year_of_Manufacturing=[]
Transmission=[]
Fuel_Type=[] 
Kms_Driven=[]
Price=[]
No_of_Owners=[]

# %%
###Getting the URL of the cars

##creating empty list for product URL

Prod_url=[]

#creating a loop to get the Url for all the cars

for i in range(0,500):
    url=driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']/li/a")
    for i in url:
        Prod_url.append(i.get_attribute('href'))
    try:
        next_btn=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']").click()
    except NoSuchElementException:
        pass
    
for i in Prod_url:
    driver.get(i)
    time.sleep(2)
    
    #getting the car brand
    try:
        Car_Brand.append(driver.find_element_by_xpath("//div[@class='_3_knn']/div/span[2]").text)
    except NoSuchElementException as e:
        Car_Brand.append('-')
        
    #getting the car model
    try:
        Car_Model.append(driver.find_element_by_xpath("//span[@data-aut-id='value_model']").text)
    except NoSuchElementException as e:
        Car_Model.append('-')
    
    #getting the car variant
    try:
        Car_Variant=[].append(driver.find_element_by_xpath("//span[@data-aut-id='value_variant']").text)
    except NoSuchElementException as e:
        Car_Variant=[].append('-')
    
    #getting the year of manufacturing
    try:
        Year_of_Manufacturing.append(driver.find_element_by_xpath("//span[@data-aut-id='value_year']").text)
    except NoSuchElementException as e:
        Year_of_Manufacturing.append('-')
    
    #getting the fuel type
    try:
        Fuel_Type.append(driver.find_element_by_xpath("//span[@data-aut-id='value_petrol']").text)
    except NoSuchElementException as e:
        Fuel_Type.append('-')
    
    #getting the transmission
    try:
        Transmission.append(driver.find_element_by_xpath("//span[@data-aut-id='value_transmission']").text)
    except NoSuchElementException as e:
        Transmission.append('-')
    
    #getting the kms run
    try:
        Kms_Driven.append(driver.find_element_by_xpath("//span[@data-aut-id='value_mileage']").text)
    except NoSuchElementException as e:
        Kms_Driven.append('-')
        
    #getting the number of owners    
    try:
        No_of_Owners.append(driver.find_element_by_xpath("//span[@data-aut-id='value_first_owner']").text)
    except NoSuchElementException as e:
        No_of_Owners.append('-')
    
    #getting the price for the car
    try:
        Price.append(driver.find_element_by_xpath("//section[@class='_2wMiF']/span[1]").text.replace('₹',''))
    except NoSuchElementException as e:
        Price.append('-')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-017d7f4c0df3> in <module>
#      22     #getting the car brand
#      23     try:
# ---> 24         Car_Brand.append(driver.find_element_by_xpath("//div[@class='_3_knn']/div/span[2]").text)
#      25     except NoSuchElementException as e:
#      26         Car_Brand.append('-')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
# ...

# %%
len(Car_Brand)
# Out:
# 3102

# %%
len(Car_Model)
# Out:
# 3102

# %%
len(Year_of_Manufacturing)
# Out:
# 3102

# %%
len(Transmission)
# Out:
# 3102

# %%
len(Fuel_Type)
# Out:
# 3102

# %%
len(Kms_Driven)
# Out:
# 3102

# %%
len(Price)
# Out:
# 3102

# %%
len(No_of_Owners)
# Out:
# 3102

# %%
#saving the data into a csv file
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
Cars_data_karnataka = pd.DataFrame({'Brand' : Car_Brand, 'Model': Car_Model , 'Variant' : Car_Variant, 'Year_of_Manufacturing' : Year_of_Manufacturing,
                     'Transmission Type' : Transmission, 'Fuel Type' : Fuel_Type, 'Kilometers Driven' : Kms_Driven, 'No of Owners' : No_of_Owners, 'Price' : Price })
Cars_data_karnataka
# Out:
#               Brand               Model Variant Year_of_Manufacturing  \
# 0     Maruti Suzuki               Swift    None                  2006
# 1        Volkswagen               Vento    None                  2014
# 2                 -                   -    None                     -
# 3           Renault              Duster    None                  2013
# 4          Mahindra              Quanto    None                  2012
# 5        Volkswagen                Polo    None                  2010
# 6           Hyundai                 i20    None                  2009
# 7     Maruti Suzuki               Swift    None                  2005
# 8            Toyota       Innova Crysta    None                  2018
# 9               BMW                  X1    None                  2013
# 10           Nissan             Terrano    None                  2013
# 11    Maruti Suzuki              Baleno    None                  2017
# ...

# %%
Cars_data_karnataka = Cars_data_karnataka.assign(Location = 'karnataka')
Cars_data_karnataka.head()
# Out:
#            Brand   Model Variant Year_of_Manufacturing Transmission Type  \
# 0  Maruti Suzuki   Swift    None                  2006            Manual
# 1     Volkswagen   Vento    None                  2014            Manual
# 2              -       -    None                     -                 -
# 3        Renault  Duster    None                  2013            Manual
# 4       Mahindra  Quanto    None                  2012            Manual
#
#   Fuel Type Kilometers Driven No of Owners      Price   Location
# 0    Petrol         68,000 km          1st   3,50,000  karnataka
# 1    Petrol         94,692 km            -   4,65,000  karnataka
# 2         -                 -            -          -  karnataka
# 3    Diesel         69,000 km          1st   6,45,000  karnataka
# 4    Diesel         85,000 km          1st   3,60,000  karnataka

# %%
#Saving in a csv file
Cars_data_karnataka.to_csv('Cars_data_karnataka.csv')
